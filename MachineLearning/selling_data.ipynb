# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score, classification_report
from sklearn.model_selection import cross_validate, train_test_split,KFold
from sklearn.linear_model import ElasticNet

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.dropna(inplace=True)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#Removendo as variáveis discretas, para realizar o estudo delas, e declarando as targets(colunas species e island).
penguins_num = penguins.drop(['species','island','sex'],axis=1)
y_species = penguins['species']
y_island = penguins['island']

x_train, x_test, y_train, y_test = train_test_split(penguins_num, y_species)
modelo_penguin_especies = LogisticRegression(multi_class='auto', max_iter=1000)

# %%
modelo_penguin_especies = LogisticRegression(multi_class='auto', max_iter=1000)
modelo_penguin_especies=modelo_penguin_especies.fit(x_train,y_train)

# %%
plt.figure(figsize=(8,8))
plt.plot(x_train, y_train)

# %%
penguins_num = penguins.drop(['species','island','sex'],axis=1)
y_species = penguins['species']
y_island = penguins['island']
en=ElasticNet() 
x=penguins_num
kf30=KFold(n_splits=30,shuffle=True)
x=kf30(x)
result_cv=cross_validate(estimator=en,X=x,y=y_species,return_train_score=True,cv=kf30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16176/3805347577.py in <module>
#       5 x=penguins_num
#       6 kf30=KFold(n_splits=30,shuffle=True)
# ----> 7 x=kf30(x)
#       8 result_cv=cross_validate(estimator=en,X=x,y=y_species,return_train_score=True,cv=kf30)
#
# TypeError: 'KFold' object is not callable

# %%
kf30=KFold(n_splits=30,shuffle=True)
x=kf30(x)
result_cv=cross_validate(estimator=en,X=x,y=y_species,return_train_score=True,cv=kf30)
